# %%
# coding: utf-8
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
from pandas.io.json import json_normalize
from apscheduler.schedulers.background import BackgroundScheduler

# from sqlalchemy import inspect
# from sqlalchemy import MetaData
# from sqlalchemy import Table
# import sqlalchemy as db

import json
import requests
import numpy as np
import pandas as pd
import datetime
import os, time
import pytz


def get_feed():
    # initialise the feed message parser from Google
    feed = gtfs_realtime_pb2.FeedMessage()
    
    # get the response from the api
    response = requests.get('http://files.transport.act.gov.au/feeds/lightrail.pb', allow_redirects=True)

    # pass the response to the Parser
    feed.ParseFromString(response.content)

    # convert to dict from our original protobuf feed
    dict_obj = MessageToDict(feed)

    return dict_obj


def get_updates(feed_obj):
    # check if empty
    if len(feed_obj) > 0:
        # get the trip updates listed on the feed
        updates = [update for update in feed_obj['entity'] if 'tripUpdate' in update]
        return updates
    else:
        return None


def updates_to_dataframe_old(updates):
    # transform feed to a data frame
    df = json_normalize(updates)
    df.columns = ['ID', 'Trip Update', 'Request Timestamp', 'Trip ID']
    df['Request Timestamp'] = pd.to_datetime(df['Request Timestamp'],unit='s')

    # parse Trip Update column
    df['Trip Update'] = df['Trip Update'].apply(lambda x: x[0])
    df_2 = json_normalize(df['Trip Update'])
    
    # change arrival time and departure time to datetime
    df_2['arrival.time'] = pd.to_datetime(df_2['arrival.time'], unit='s')
    df_2['departure.time'] = pd.to_datetime(df_2['departure.time'], unit='s')

    # combine data frames
    updates_df = pd.concat([df, df_2],axis=1)
    updates_df.rename(inplace=True, columns=
        {
            'arrival.time':'Arrival Time',
            'arrival.delay':'Arrival Delay',
            'departure.time':'Departure Time',
            'departure.delay':'Departure Delay'
        })

    # drop unnecessary colimns
    updates_df.drop(['ID', 'Trip Update', 'arrival.uncertainty', 'departure.uncertainty'], axis=1, inplace=True)
    
    # set time zone
    updates_df['Request Timestamp'] = updates_df['Request Timestamp'].dt.tz_localize('UTC').dt.tz_convert('Australia/Canberra')
    updates_df['Arrival Time'] = updates_df['Arrival Time'].dt.tz_localize('UTC').dt.tz_convert('Australia/Canberra')
    updates_df['Departure Time'] = updates_df['Departure Time'].dt.tz_localize('UTC').dt.tz_convert('Australia/Canberra')
    
    return updates_df


def updates_to_dataframe(updates):
    # transform feed to a dataframe 
    df = json_normalize(updates)
    df['tripUpdate.stopTimeUpdate'] = df['tripUpdate.stopTimeUpdate'].apply(lambda x: x[0])
    print("length of updates: {}".format(len(updates))) # debug: print number of updates in the feed
    
    # format feed
    x = json_normalize(df['tripUpdate.stopTimeUpdate'])
    x['tripUpdate.trip.tripId'] = df['tripUpdate.trip.tripId']
    x['tripUpdate.timestamp'] = df['tripUpdate.timestamp']
    x['tripUpdate.delay'] = df['tripUpdate.delay']

    # format date time
    x['arrival.time'] = x['arrival.time'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))
    x['departure.time'] = x['departure.time'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))
    x['tripUpdate.timestamp'] = x['tripUpdate.timestamp'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))

    # transform to datetime
    x['arrival.time'] = pd.to_datetime(x['arrival.time'])
    x['departure.time'] = pd.to_datetime(x['departure.time'])
    x['tripUpdate.timestamp'] = pd.to_datetime(x['tripUpdate.timestamp'])

    return x


def validate(updates):
    if updates is None:
        print('Feed is empty')
        return False

    else:
        return True

# %% [markdown]
# ---
# # Get Trip Updates

# %%
feed = get_feed() # get raw feed
updates = get_updates(feed) # get trip updates
df = updates_to_dataframe(updates) # transform updates to dataframe
# Out:
# length of updates: 129

# %% [markdown]
# # Write Feed to CSV

# %%
# df.to_csv('updates/update.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 12 columns):
# arrival.delay             129 non-null int64
# arrival.time              129 non-null datetime64[ns]
# arrival.uncertainty       129 non-null int64
# departure.delay           129 non-null int64
# departure.time            129 non-null datetime64[ns]
# departure.uncertainty     129 non-null int64
# scheduleRelationship      129 non-null object
# stopId                    129 non-null object
# stopSequence              129 non-null int64
# tripUpdate.trip.tripId    129 non-null object
# tripUpdate.timestamp      129 non-null datetime64[ns]
# tripUpdate.delay          129 non-null int64
# dtypes: datetime64[ns](3), int64(6), object(3)
# memory usage: 12.2+ KB

# %%
df.head()
# Out:
#    arrival.delay        arrival.time  arrival.uncertainty  departure.delay  \
# 0             -6 2019-06-02 08:23:54                    0               -6
# 1            196 2019-06-02 08:57:16                    0              196
# 2              1 2019-06-02 09:24:01                    0                1
# 3             -9 2019-06-02 09:53:51                    0               -9
# 4             -9 2019-06-02 10:23:51                    0               -9
#
#        departure.time  departure.uncertainty scheduleRelationship stopId  \
# 0 2019-06-02 08:23:54                      0            SCHEDULED   8129
# 1 2019-06-02 08:57:16                      0            SCHEDULED   8100
# 2 2019-06-02 09:24:01                      0            SCHEDULED   8129
# 3 2019-06-02 09:53:51                      0            SCHEDULED   8100
# 4 2019-06-02 10:23:51                      0            SCHEDULED   8129
#
#    stopSequence tripUpdate.trip.tripId tripUpdate.timestamp  tripUpdate.delay
# 0            13                    780  2019-06-02 20:26:00                 0
# 1            13                    718  2019-06-02 20:26:00                 0
# 2            13                    784  2019-06-02 20:26:00                 0
# 3            13                    722  2019-06-02 20:26:00                 0
# 4            13                    788  2019-06-02 20:26:00                 0

# %%
x = datetime.datetime.now()
x
# Out:
# datetime.datetime(2019, 6, 2, 20, 26, 53, 682235)

# %%
x.hour
# Out:
# 20

# %%
x.minute
# Out:
# 26

# %%
x + pd.Timedelta(minutes=30)
# Out:
# datetime.datetime(2019, 6, 2, 20, 56, 53, 682235)

# %%
df[(df['arrival.time'] >= datetime.datetime.now() - pd.Timedelta(minutes=15)) & (df['arrival.time'] <= datetime.datetime.now() + pd.Timedelta(minutes=15))]
# Out:
#      arrival.delay        arrival.time  arrival.uncertainty  departure.delay  \
# 24              26 2019-06-02 20:24:26                    0               26
# 25               0 2019-06-02 20:30:00                    1                0
# 58               1 2019-06-02 20:26:10                    0                1
# 59               0 2019-06-02 20:45:00                    1                0
# 89              -8 2019-06-02 20:23:52                    0               -8
# 90               0 2019-06-02 20:30:00                    1                0
# 121             -6 2019-06-02 20:25:39                    0               -6
# 122              0 2019-06-02 20:45:00                    1                0
#
#          departure.time  departure.uncertainty scheduleRelationship stopId  \
# 24  2019-06-02 20:24:26                      0            SCHEDULED   8129
# 25  2019-06-02 20:30:00                      1            SCHEDULED   8129
# 58  2019-06-02 20:26:30                      0            SCHEDULED   8114
# 59  2019-06-02 20:45:00                      1            SCHEDULED   8129
# 89  2019-06-02 20:23:52                      0            SCHEDULED   8100
# 90  2019-06-02 20:30:00                      1            SCHEDULED   8100
# 121 2019-06-02 20:25:59                      0            SCHEDULED   8117
# 122 2019-06-02 20:45:00                      1            SCHEDULED   8100
#
#      stopSequence tripUpdate.trip.tripId tripUpdate.timestamp  \
# 24             13                    828  2019-06-02 20:26:00
# 25              1                    766  2019-06-02 20:26:00
# 58              6                    829  2019-06-02 20:26:00
# 59              1                    767  2019-06-02 20:26:00
# 89             13                    764  2019-06-02 20:26:00
# 90              1                    830  2019-06-02 20:26:00
# 121             7                    765  2019-06-02 20:26:00
# 122             1                    831  2019-06-02 20:26:00
#
#      tripUpdate.delay
# 24                  0
# 25                  0
# 58                  0
# 59                  0
# 89                  0
# 90                  0
# 121                 0
# 122                 0

# %%
trips = pd.read_csv('../GTFS/google_transit_lr/trips.txt')
trips = trips[trips['route_id'] == 'ACTO001']

# %%
stop_times = pd.read_csv('../GTFS/google_transit_lr/stop_times.txt')

# %%
trips.head()
# Out:
#   route_id service_id  trip_id trip_headsign  direction_id block_id  shape_id  \
# 1  ACTO001         SU      780     Alinga St             1        3      1003
# 2  ACTO001         SU      718  Gungahlin Pl             0        3      1004
# 3  ACTO001         SU      784     Alinga St             1        3      1003
# 4  ACTO001         SU      722  Gungahlin Pl             0        3      1004
# 5  ACTO001         SU      788     Alinga St             1        3      1003
#
#    wheelchair_accessible  bikes_allowed
# 1                      1              1
# 2                      1              1
# 3                      1              1
# 4                      1              1
# 5                      1              1

# %%
stop_times.head()
# Out:
#    trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0      712     07:36:16       07:36:36     8111              1
# 1      712     07:38:20       07:38:40     8109              2
# 2      712     07:39:51       07:40:11     8107              3
# 3      712     07:41:45       07:42:05     8105              4
# 4      712     07:43:43       07:43:43     8100              5
#
#             stop_headsign  pickup_type  drop_off_type  timepoint
# 0      Well Station Drive            0              0          1
# 1        Nullarbor Avenue            0              0          1
# 2         Mapleton Avenue            0              0          1
# 3  Manning Clark Crescent            0              0          1
# 4         Gungahlin Place            0              0          1

# %%
ref = pd.merge(left=trips, left_on='trip_id', right=stop_times, right_on='trip_id', how='inner')

# %%
ref = ref[['service_id', 'trip_id', 'trip_headsign', 'direction_id', 'arrival_time', 'departure_time', 'stop_sequence', 'stop_headsign']]

# %%
ref.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9243 entries, 0 to 9242
# Data columns (total 8 columns):
# service_id        9243 non-null object
# trip_id           9243 non-null int64
# trip_headsign     9243 non-null object
# direction_id      9243 non-null int64
# arrival_time      9243 non-null object
# departure_time    9243 non-null object
# stop_sequence     9243 non-null int64
# stop_headsign     9243 non-null object
# dtypes: int64(3), object(5)
# memory usage: 649.9+ KB

# %%
ref.head()
# Out:
#   service_id  trip_id trip_headsign  direction_id arrival_time departure_time  \
# 0         SU      780     Alinga St             1     08:00:00       08:00:00
# 1         SU      780     Alinga St             1     08:02:04       08:02:24
# 2         SU      780     Alinga St             1     08:04:04       08:04:24
# 3         SU      780     Alinga St             1     08:05:40       08:06:00
# 4         SU      780     Alinga St             1     08:07:31       08:07:51
#
#    stop_sequence           stop_headsign
# 0              1         Gungahlin Place
# 1              2  Manning Clark Crescent
# 2              3         Mapleton Avenue
# 3              4        Nullarbor Avenue
# 4              5      Well Station Drive

# %%
ref['service_id'].unique()
# Out:
# array(['SU', 'WD', 'FR', 'SA'], dtype=object)

# %%
arrival_time = ref['arrival_time']

# %%
for idx, value in enumerate(arrival_time):
    string = value.split(':')
    if string[0] == '24':
        string[0] = '00'
    elif string[0] == '25':
        string[0] = '01'
    else:
        continue
    arrival_time[idx] = ':'.join(string)
# Out:
# /Users/noelangelo/miniconda3/envs/data-science/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ref['arrival_time'] = arrival_time

# %%
ref['arrival_time'] = ref['arrival_time'].apply(lambda x: datetime.datetime.strptime(x, '%H:%M:%S').time())

# %%
departure_time = ref['departure_time']

# %%
for idx, value in enumerate(departure_time):
    string = value.split(':')
    if string[0] == '24':
        string[0] = '00'
    elif string[0] == '25':
        string[0] = '01'
    else:
        continue
    departure_time[idx] = ':'.join(string)
# Out:
# /Users/noelangelo/miniconda3/envs/data-science/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ref['departure_time'] = departure_timere_time
ref['departure_time'] = ref['departure_time'].apply(lambda x: datetime.datetime.strptime(x, '%H:%M:%S').time())

# %%
ref.head()
# Out:
#   service_id  trip_id trip_headsign  direction_id arrival_time departure_time  \
# 0         SU      780     Alinga St             1     08:00:00       08:00:00
# 1         SU      780     Alinga St             1     08:02:04       08:02:24
# 2         SU      780     Alinga St             1     08:04:04       08:04:24
# 3         SU      780     Alinga St             1     08:05:40       08:06:00
# 4         SU      780     Alinga St             1     08:07:31       08:07:51
#
#    stop_sequence           stop_headsign
# 0              1         Gungahlin Place
# 1              2  Manning Clark Crescent
# 2              3         Mapleton Avenue
# 3              4        Nullarbor Avenue
# 4              5      Well Station Drive

# %%
ref[ref['arrival_time'] <= datetime.time(hour=9)]
# Out:
#      service_id  trip_id trip_headsign  direction_id arrival_time  \
# 0            SU      780     Alinga St             1     08:00:00
# 1            SU      780     Alinga St             1     08:02:04
# 2            SU      780     Alinga St             1     08:04:04
# 3            SU      780     Alinga St             1     08:05:40
# 4            SU      780     Alinga St             1     08:07:31
# 5            SU      780     Alinga St             1     08:11:09
# 6            SU      780     Alinga St             1     08:13:25
# 7            SU      780     Alinga St             1     08:15:34
# 8            SU      780     Alinga St             1     08:17:17
# 9            SU      780     Alinga St             1     08:19:17
# 10           SU      780     Alinga St             1     08:20:35
# 11           SU      780     Alinga St             1     08:22:13
# 12           SU      780     Alinga St             1     08:24:00
# 13           SU      718  Gungahlin Pl             0     08:30:00
# 14           SU      718  Gungahlin Pl             0     08:31:54
# 15           SU      718  Gungahlin Pl             0     08:33:24
# 16           SU      718  Gungahlin Pl             0     08:34:45
# 17           SU      718  Gungahlin Pl             0     08:36:44
# 18           SU      718  Gungahlin Pl             0     08:38:41
# 19           SU      718  Gungahlin Pl             0     08:40:45
# 20           SU      718  Gungahlin Pl             0     08:43:00
# 21           SU      718  Gungahlin Pl             0     08:46:33
# 22           SU      718  Gungahlin Pl             0     08:48:37
# 23           SU      718  Gungahlin Pl             0     08:50:08
# 24           SU      718  Gungahlin Pl             0     08:52:02
# 25           SU      718  Gungahlin Pl             0     08:54:00
# 26           SU      784     Alinga St             1     09:00:00
# 416          SU      781     Alinga St             1     08:15:00
# 417          SU      781     Alinga St             1     08:17:04
# 418          SU      781     Alinga St             1     08:19:04
# ...         ...      ...           ...           ...          ...
# 8823         SA      558  Gungahlin Pl             0     08:33:37
# 8824         SA      558  Gungahlin Pl             0     08:35:08
# 8825         SA      558  Gungahlin Pl             0     08:37:02
# 8826         SA      558  Gungahlin Pl             0     08:39:00
# 8827         SA      640     Alinga St             1     08:45:00
# 8828         SA      640     Alinga St             1     08:47:04
# 8829         SA      640     Alinga St             1     08:49:04
# 8830         SA      640     Alinga St             1     08:50:40
# 8831         SA      640     Alinga St             1     08:52:31
# 8832         SA      640     Alinga St             1     08:56:09
# 8833         SA      640     Alinga St             1     08:58:25
# 9224         SA      700     Alinga St             1     00:00:34
# 9225         SA      700     Alinga St             1     00:02:17
# 9226         SA      700     Alinga St             1     00:04:17
# 9227         SA      700     Alinga St             1     00:05:35
# 9228         SA      700     Alinga St             1     00:07:13
# 9229         SA      700     Alinga St             1     00:09:00
# 9230         SA      622  Gungahlin Pl             0     00:15:00
# 9231         SA      622  Gungahlin Pl             0     00:16:54
# 9232         SA      622  Gungahlin Pl             0     00:18:24
# 9233         SA      622  Gungahlin Pl             0     00:19:45
# 9234         SA      622  Gungahlin Pl             0     00:21:44
# 9235         SA      622  Gungahlin Pl             0     00:23:41
# 9236         SA      622  Gungahlin Pl             0     00:25:45
# 9237         SA      622  Gungahlin Pl             0     00:28:00
# 9238         SA      622  Gungahlin Pl             0     00:31:33
# 9239         SA      622  Gungahlin Pl             0     00:33:37
# 9240         SA      622  Gungahlin Pl             0     00:35:08
# 9241         SA      622  Gungahlin Pl             0     00:37:02
# 9242         SA      622  Gungahlin Pl             0     00:39:00
#
#      departure_time  stop_sequence           stop_headsign
# 0          08:00:00              1         Gungahlin Place
# 1          08:02:24              2  Manning Clark Crescent
# 2          08:04:24              3         Mapleton Avenue
# 3          08:06:00              4        Nullarbor Avenue
# 4          08:07:51              5      Well Station Drive
# 5          08:11:29              6     EPIC and Racecourse
# 6          08:13:45              7          Phillip Avenue
# 7          08:15:54              8          Swinden Street
# 8          08:17:37              9     Dickson Interchange
# 9          08:19:37             10        Macarthur Avenue
# 10         08:20:55             11            Ipima Street
# 11         08:22:33             12          Elouera Street
# 12         08:24:00             13           Alinga Street
# 13         08:30:00              1           Alinga Street
# 14         08:32:14              2          Elouera Street
# 15         08:33:44              3            Ipima Street
# 16         08:35:05              4        Macarthur Avenue
# 17         08:37:04              5     Dickson Interchange
# 18         08:39:01              6          Swinden Street
# 19         08:41:05              7          Phillip Avenue
# 20         08:43:20              8     EPIC and Racecourse
# 21         08:46:53              9      Well Station Drive
# 22         08:48:57             10        Nullarbor Avenue
# 23         08:50:28             11         Mapleton Avenue
# 24         08:52:22             12  Manning Clark Crescent
# 25         08:54:00             13         Gungahlin Place
# 26         09:00:00              1         Gungahlin Place
# 416        08:15:00              1         Gungahlin Place
# 417        08:17:24              2  Manning Clark Crescent
# 418        08:19:24              3         Mapleton Avenue
# ...             ...            ...                     ...
# 8823       08:33:57             10        Nullarbor Avenue
# 8824       08:35:28             11         Mapleton Avenue
# 8825       08:37:22             12  Manning Clark Crescent
# 8826       08:39:00             13         Gungahlin Place
# 8827       08:45:00              1         Gungahlin Place
# 8828       08:47:24              2  Manning Clark Crescent
# 8829       08:49:24              3         Mapleton Avenue
# 8830       08:51:00              4        Nullarbor Avenue
# 8831       08:52:51              5      Well Station Drive
# 8832       08:56:29              6     EPIC and Racecourse
# 8833       08:58:45              7          Phillip Avenue
# 9224       00:00:54              8          Swinden Street
# 9225       00:02:37              9     Dickson Interchange
# 9226       00:04:37             10        Macarthur Avenue
# 9227       00:05:55             11            Ipima Street
# 9228       00:07:33             12          Elouera Street
# 9229       00:09:00             13           Alinga Street
# 9230       00:15:00              1           Alinga Street
# 9231       00:17:14              2          Elouera Street
# 9232       00:18:44              3            Ipima Street
# 9233       00:20:05              4        Macarthur Avenue
# 9234       00:22:04              5     Dickson Interchange
# 9235       00:24:01              6          Swinden Street
# 9236       00:26:05              7          Phillip Avenue
# 9237       00:28:20              8     EPIC and Racecourse
# 9238       00:31:53              9      Well Station Drive
# 9239       00:33:57             10        Nullarbor Avenue
# 9240       00:35:28             11         Mapleton Avenue
# 9241       00:37:22             12  Manning Clark Crescent
# 9242       00:39:00             13         Gungahlin Place
#
# [1737 rows x 8 columns]
