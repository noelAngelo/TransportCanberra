# %%
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
from pandas.io.json import json_normalize
# from apscheduler.schedulers.background import BackgroundScheduler

from sqlalchemy import inspect
from sqlalchemy import MetaData
from sqlalchemy import Table
import sqlalchemy as db

import json
import requests
import numpy as np
import pandas as pd
import datetime
from datetime import timedelta 
import os, time
import pytz

# %%
def get_feed():
    # initialise the feed message parser from Google
    feed = gtfs_realtime_pb2.FeedMessage()
    
    # get the response from the api
    response = requests.get('http://files.transport.act.gov.au/feeds/lightrail.pb', allow_redirects=True)

    # pass the response to the Parser
    feed.ParseFromString(response.content)

    # convert to dict from our original protobuf feed
    dict_obj = MessageToDict(feed)

    return dict_obj

# %%
def get_updates(feed_obj):
    # check if empty
    if len(feed_obj) > 0:
        # get the trip updates listed on the feed
        updates = [update for update in feed_obj['entity'] if 'tripUpdate' in update]
        return updates
    else:
        return None

# %%
def updates_to_dataframe(updates):
    # transform feed to a dataframe 
    df = json_normalize(updates)
    df['tripUpdate.stopTimeUpdate'] = df['tripUpdate.stopTimeUpdate'].apply(lambda x: x[0])
    print("length of updates: {}".format(len(updates))) # debug: print number of updates in the feed
    
    # format feed
    x = json_normalize(df['tripUpdate.stopTimeUpdate'])
    x['tripUpdate.trip.tripId'] = df['tripUpdate.trip.tripId']
    x['tripUpdate.timestamp'] = df['tripUpdate.timestamp']
    x['tripUpdate.delay'] = df['tripUpdate.delay']
    x['id'] = df['id']

    # format date time
    x['arrival.time'] = x['arrival.time'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))
    x['departure.time'] = x['departure.time'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))
    x['tripUpdate.timestamp'] = x['tripUpdate.timestamp'].apply(lambda xx: datetime.datetime.fromtimestamp(int(xx)))

    # transform to datetime
    x['arrival.time'] = pd.to_datetime(x['arrival.time'])
    x['departure.time'] = pd.to_datetime(x['departure.time'])
    x['tripUpdate.timestamp'] = pd.to_datetime(x['tripUpdate.timestamp'])

    return x

# %%
def validate(updates):
    if updates is None:
        print('Feed is empty')
        return False

    else:
        return True

# %%
df = updates_to_dataframe(get_updates(get_feed()))
df
# Out:
# length of updates: 250
#      arrival.delay        arrival.time  arrival.uncertainty  departure.delay  \
# 0               30 2019-06-14 06:24:30                    0               30
# 1               24 2019-06-14 06:54:24                    0               24
# 2               46 2019-06-14 07:24:46                    0               46
# 3               14 2019-06-14 07:32:08                    0               14
# 4                0 2019-06-14 08:00:00                    1                0
# 5                0 2019-06-14 08:30:00                    1                0
# 6                0 2019-06-14 09:00:00                    1                0
# 7                0 2019-06-14 09:30:00                    1                0
# 8                0 2019-06-14 10:00:00                    1                0
# 9                0 2019-06-14 10:30:00                    1                0
# 10               0 2019-06-14 11:00:00                    1                0
# 11               0 2019-06-14 11:30:00                    1                0
# 12               0 2019-06-14 12:00:00                    1                0
# 13               0 2019-06-14 12:30:00                    1                0
# 14               0 2019-06-14 13:00:00                    1                0
# 15               0 2019-06-14 13:30:00                    1                0
# 16               0 2019-06-14 14:00:00                    1                0
# 17               0 2019-06-14 14:30:00                    1                0
# 18               0 2019-06-14 15:00:00                    1                0
# 19               0 2019-06-14 15:30:00                    1                0
# 20               0 2019-06-14 16:00:00                    1                0
# 21               0 2019-06-14 16:30:00                    1                0
# 22               0 2019-06-14 17:00:00                    1                0
# 23               0 2019-06-14 17:30:00                    1                0
# 24               0 2019-06-14 18:00:00                    1                0
# 25               0 2019-06-14 18:30:00                    1                0
# 26               0 2019-06-14 19:00:00                    1                0
# 27               0 2019-06-14 19:30:00                    1                0
# 28               0 2019-06-14 20:00:00                    1                0
# 29               0 2019-06-14 20:30:00                    1                0
# ..             ...                 ...                  ...              ...
# 220              0 2019-06-14 16:18:00                    1                0
# 221              0 2019-06-14 16:48:00                    1                0
# 222              0 2019-06-14 17:18:00                    1                0
# 223              0 2019-06-14 17:48:00                    1                0
# 224              0 2019-06-14 18:16:00                    1                0
# 225              0 2019-06-14 15:47:22                    1                0
# 226              0 2019-06-14 16:06:00                    1                0
# 227              0 2019-06-14 16:36:00                    1                0
# 228              0 2019-06-14 17:06:00                    1                0
# 229              0 2019-06-14 17:40:00                    1                0
# 230              0 2019-06-14 18:15:00                    1                0
# 231              0 2019-06-14 18:45:00                    1                0
# 232              0 2019-06-14 19:15:00                    1                0
# 233              0 2019-06-14 19:45:00                    1                0
# 234              0 2019-06-14 20:15:00                    1                0
# 235              0 2019-06-14 20:45:00                    1                0
# 236              0 2019-06-14 21:15:00                    1                0
# 237              0 2019-06-14 21:45:00                    1                0
# 238              0 2019-06-14 22:15:00                    1                0
# 239              0 2019-06-14 22:45:00                    1                0
# 240              0 2019-06-14 23:15:00                    1                0
# 241              0 2019-06-14 23:45:00                    1                0
# 242              0 2019-06-15 00:15:00                    1                0
# 243              0 2019-06-15 00:42:00                    1                0
# 244              0 2019-06-14 15:57:22                    1                0
# 245              0 2019-06-14 16:18:00                    1                0
# 246              0 2019-06-14 16:48:00                    1                0
# 247              0 2019-06-14 17:18:00                    1                0
# 248              0 2019-06-14 17:50:00                    1                0
# 249              0 2019-06-14 18:17:00                    1                0
#
#          departure.time  departure.uncertainty scheduleRelationship stopId  \
# 0   2019-06-14 06:24:30                      0            SCHEDULED   8129
# 1   2019-06-14 06:54:24                      0            SCHEDULED   8100
# 2   2019-06-14 07:24:46                      0            SCHEDULED   8129
# 3   2019-06-14 07:32:28                      0            SCHEDULED   8127
# 4   2019-06-14 08:00:00                      1            SCHEDULED   8100
# 5   2019-06-14 08:30:00                      1            SCHEDULED   8129
# 6   2019-06-14 09:00:00                      1            SCHEDULED   8100
# 7   2019-06-14 09:30:00                      1            SCHEDULED   8129
# 8   2019-06-14 10:00:00                      1            SCHEDULED   8100
# 9   2019-06-14 10:30:00                      1            SCHEDULED   8129
# 10  2019-06-14 11:00:00                      1            SCHEDULED   8100
# 11  2019-06-14 11:30:00                      1            SCHEDULED   8129
# 12  2019-06-14 12:00:00                      1            SCHEDULED   8100
# 13  2019-06-14 12:30:00                      1            SCHEDULED   8129
# 14  2019-06-14 13:00:00                      1            SCHEDULED   8100
# 15  2019-06-14 13:30:00                      1            SCHEDULED   8129
# 16  2019-06-14 14:00:00                      1            SCHEDULED   8100
# 17  2019-06-14 14:30:00                      1            SCHEDULED   8129
# 18  2019-06-14 15:00:00                      1            SCHEDULED   8100
# 19  2019-06-14 15:30:00                      1            SCHEDULED   8129
# 20  2019-06-14 16:00:00                      1            SCHEDULED   8100
# 21  2019-06-14 16:30:00                      1            SCHEDULED   8129
# 22  2019-06-14 17:00:00                      1            SCHEDULED   8100
# 23  2019-06-14 17:30:00                      1            SCHEDULED   8129
# 24  2019-06-14 18:00:00                      1            SCHEDULED   8100
# 25  2019-06-14 18:30:00                      1            SCHEDULED   8129
# 26  2019-06-14 19:00:00                      1            SCHEDULED   8100
# 27  2019-06-14 19:30:00                      1            SCHEDULED   8129
# 28  2019-06-14 20:00:00                      1            SCHEDULED   8100
# 29  2019-06-14 20:30:00                      1            SCHEDULED   8129
# ..                  ...                    ...                  ...    ...
# 220 2019-06-14 16:18:00                      1            SCHEDULED   8100
# 221 2019-06-14 16:48:00                      1            SCHEDULED   8129
# 222 2019-06-14 17:18:00                      1            SCHEDULED   8100
# 223 2019-06-14 17:48:00                      1            SCHEDULED   8129
# 224 2019-06-14 18:16:00                      1            SCHEDULED   8100
# 225 2019-06-14 15:47:22                      1            SCHEDULED   8114
# 226 2019-06-14 16:06:00                      1            SCHEDULED   8129
# 227 2019-06-14 16:36:00                      1            SCHEDULED   8100
# 228 2019-06-14 17:06:00                      1            SCHEDULED   8129
# 229 2019-06-14 17:40:00                      1            SCHEDULED   8100
# 230 2019-06-14 18:15:00                      1            SCHEDULED   8129
# 231 2019-06-14 18:45:00                      1            SCHEDULED   8100
# 232 2019-06-14 19:15:00                      1            SCHEDULED   8129
# 233 2019-06-14 19:45:00                      1            SCHEDULED   8100
# 234 2019-06-14 20:15:00                      1            SCHEDULED   8129
# 235 2019-06-14 20:45:00                      1            SCHEDULED   8100
# 236 2019-06-14 21:15:00                      1            SCHEDULED   8129
# 237 2019-06-14 21:45:00                      1            SCHEDULED   8100
# 238 2019-06-14 22:15:00                      1            SCHEDULED   8129
# 239 2019-06-14 22:45:00                      1            SCHEDULED   8100
# 240 2019-06-14 23:15:00                      1            SCHEDULED   8129
# 241 2019-06-14 23:45:00                      1            SCHEDULED   8100
# 242 2019-06-15 00:15:00                      1            SCHEDULED   8129
# 243 2019-06-15 00:42:00                      1            SCHEDULED   8100
# 244 2019-06-14 15:57:22                      1            SCHEDULED   8114
# 245 2019-06-14 16:18:00                      1            SCHEDULED   8129
# 246 2019-06-14 16:48:00                      1            SCHEDULED   8100
# 247 2019-06-14 17:18:00                      1            SCHEDULED   8129
# 248 2019-06-14 17:50:00                      1            SCHEDULED   8100
# 249 2019-06-14 18:17:00                      1            SCHEDULED   8129
#
#      stopSequence tripUpdate.trip.tripId tripUpdate.timestamp  \
# 0              13                    407  2019-06-14 07:31:45
# 1              13                    273  2019-06-14 07:31:45
# 2              13                    413  2019-06-14 07:31:45
# 3               2                    288  2019-06-14 07:31:45
# 4               1                    423  2019-06-14 07:31:45
# 5               1                    298  2019-06-14 07:31:45
# 6               1                    433  2019-06-14 07:31:45
# 7               1                    310  2019-06-14 07:31:45
# 8               1                    443  2019-06-14 07:31:45
# 9               1                    316  2019-06-14 07:31:45
# 10              1                    449  2019-06-14 07:31:45
# 11              1                    322  2019-06-14 07:31:45
# 12              1                    455  2019-06-14 07:31:45
# 13              1                    328  2019-06-14 07:31:45
# 14              1                    461  2019-06-14 07:31:45
# 15              1                    334  2019-06-14 07:31:45
# 16              1                    467  2019-06-14 07:31:45
# 17              1                    340  2019-06-14 07:31:45
# 18              1                    473  2019-06-14 07:31:45
# 19              1                    346  2019-06-14 07:31:45
# 20              1                    483  2019-06-14 07:31:45
# 21              1                    358  2019-06-14 07:31:45
# 22              1                    493  2019-06-14 07:31:45
# 23              1                    368  2019-06-14 07:31:45
# 24              1                    505  2019-06-14 07:31:45
# 25              1                    377  2019-06-14 07:31:45
# 26              1                    515  2019-06-14 07:31:45
# 27              1                    381  2019-06-14 07:31:45
# 28              1                    519  2019-06-14 07:31:45
# 29              1                    385  2019-06-14 07:31:45
# ..            ...                    ...                  ...
# 220             1                    486  2019-06-14 07:31:45
# 221             1                    361  2019-06-14 07:31:45
# 222             1                    496  2019-06-14 07:31:45
# 223             1                    371  2019-06-14 07:31:45
# 224             1                    509  2019-06-14 07:31:45
# 225             1                    478  2019-06-14 07:31:45
# 226             1                    354  2019-06-14 07:31:45
# 227             1                    489  2019-06-14 07:31:45
# 228             1                    364  2019-06-14 07:31:45
# 229             1                    501  2019-06-14 07:31:45
# 230             1                    374  2019-06-14 07:31:45
# 231             1                    514  2019-06-14 07:31:45
# 232             1                    380  2019-06-14 07:31:45
# 233             1                    518  2019-06-14 07:31:45
# 234             1                    384  2019-06-14 07:31:45
# 235             1                    522  2019-06-14 07:31:45
# 236             1                    388  2019-06-14 07:31:45
# 237             1                    526  2019-06-14 07:31:45
# 238             1                    392  2019-06-14 07:31:45
# 239             1                    530  2019-06-14 07:31:45
# 240             1                    396  2019-06-14 07:31:45
# 241             1                    534  2019-06-14 07:31:45
# 242             1                    400  2019-06-14 07:31:45
# 243             1                    538  2019-06-14 07:31:45
# 244             1                    481  2019-06-14 07:31:45
# 245             1                    356  2019-06-14 07:31:45
# 246             1                    491  2019-06-14 07:31:45
# 247             1                    366  2019-06-14 07:31:45
# 248             1                    502  2019-06-14 07:31:45
# 249             1                    375  2019-06-14 07:31:45
#
#      tripUpdate.delay        id
# 0                   0  13783017
# 1                   0  13783018
# 2                   0  13783019
# 3                   0  13783020
# 4                   0  13783021
# 5                   0  13783022
# 6                   0  13783023
# 7                   0  13783024
# 8                   0  13783025
# 9                   0  13783026
# 10                  0  13783027
# 11                  0  13783028
# 12                  0  13783029
# 13                  0  13783030
# 14                  0  13783031
# 15                  0  13783032
# 16                  0  13783033
# 17                  0  13783034
# 18                  0  13783035
# 19                  0  13783036
# 20                  0  13783037
# 21                  0  13783038
# 22                  0  13783039
# 23                  0  13783040
# 24                  0  13783041
# 25                  0  13783042
# 26                  0  13783043
# 27                  0  13783044
# 28                  0  13783045
# 29                  0  13783046
# ..                ...       ...
# 220                 0  13783237
# 221                 0  13783238
# 222                 0  13783239
# 223                 0  13783240
# 224                 0  13783241
# 225                 0  13783242
# 226                 0  13783243
# 227                 0  13783244
# 228                 0  13783245
# 229                 0  13783246
# 230                 0  13783247
# 231                 0  13783248
# 232                 0  13783249
# 233                 0  13783250
# 234                 0  13783251
# 235                 0  13783252
# 236                 0  13783253
# 237                 0  13783254
# 238                 0  13783255
# 239                 0  13783256
# 240                 0  13783257
# 241                 0  13783258
# 242                 0  13783259
# 243                 0  13783260
# 244                 0  13783261
# 245                 0  13783262
# 246                 0  13783263
# 247                 0  13783264
# 248                 0  13783265
# 249                 0  13783266
#
# [250 rows x 13 columns]

# %%
df.columns = ['Arrival Delay', 'Arrival Time', 'Arrival Uncertainty',
       'Departure Delay', 'Departure Time', 'Departure Uncertainty',
       'Schedule Relationship', 'Stop ID', 'Stop Sequence', 'Trip ID',
       'Request Timestamp', 'Delay', 'Feed ID']

# %%
len(df['Trip ID'].unique())
# Out:
# 250

# %%
df = df.set_index('Arrival Time')

# %%
start = datetime.datetime.now() - datetime.timedelta(minutes=1) 
end = datetime.datetime.now() + datetime.timedelta(minutes=1)

# %%
start = datetime.datetime.strftime(start, '%H:%M')
end = datetime.datetime.strftime(end, '%H:%M')

# %%
df.head()
# Out:
#                      Arrival Delay  Arrival Uncertainty  Departure Delay  \
# Arrival Time
# 2019-06-14 06:24:30             30                    0               30
# 2019-06-14 06:54:24             24                    0               24
# 2019-06-14 07:24:46             46                    0               46
# 2019-06-14 07:32:08             14                    0               14
# 2019-06-14 08:00:00              0                    1                0
#
#                          Departure Time  Departure Uncertainty  \
# Arrival Time
# 2019-06-14 06:24:30 2019-06-14 06:24:30                      0
# 2019-06-14 06:54:24 2019-06-14 06:54:24                      0
# 2019-06-14 07:24:46 2019-06-14 07:24:46                      0
# 2019-06-14 07:32:08 2019-06-14 07:32:28                      0
# 2019-06-14 08:00:00 2019-06-14 08:00:00                      1
#
#                     Schedule Relationship Stop ID  Stop Sequence Trip ID  \
# Arrival Time
# 2019-06-14 06:24:30             SCHEDULED    8129             13     407
# 2019-06-14 06:54:24             SCHEDULED    8100             13     273
# 2019-06-14 07:24:46             SCHEDULED    8129             13     413
# 2019-06-14 07:32:08             SCHEDULED    8127              2     288
# 2019-06-14 08:00:00             SCHEDULED    8100              1     423
#
#                       Request Timestamp  Delay   Feed ID
# Arrival Time
# 2019-06-14 06:24:30 2019-06-14 07:31:45      0  13783017
# 2019-06-14 06:54:24 2019-06-14 07:31:45      0  13783018
# 2019-06-14 07:24:46 2019-06-14 07:31:45      0  13783019
# 2019-06-14 07:32:08 2019-06-14 07:31:45      0  13783020
# 2019-06-14 08:00:00 2019-06-14 07:31:45      0  13783021

# %%
print( start, end )
df = df.between_time(start, end)
df
# Out:
# 07:31 07:33
#                      Arrival Delay  Arrival Uncertainty  Departure Delay  \
# Arrival Time
# 2019-06-14 07:32:08             14                    0               14
# 2019-06-14 07:31:40            -24                    0              -24
# 2019-06-14 07:32:25            -35                    0              -35
# 2019-06-14 07:31:50             33                    0               33
# 2019-06-14 07:31:06            -25                    0              -25
# 2019-06-14 07:32:33              0                    1                0
#
#                          Departure Time  Departure Uncertainty  \
# Arrival Time
# 2019-06-14 07:32:08 2019-06-14 07:32:28                      0
# 2019-06-14 07:31:40 2019-06-14 07:32:00                      0
# 2019-06-14 07:32:25 2019-06-14 07:32:45                      0
# 2019-06-14 07:31:50 2019-06-14 07:32:10                      0
# 2019-06-14 07:31:06 2019-06-14 07:31:26                      0
# 2019-06-14 07:32:33 2019-06-14 07:32:33                      1
#
#                     Schedule Relationship Stop ID  Stop Sequence Trip ID  \
# Arrival Time
# 2019-06-14 07:32:08             SCHEDULED    8127              2     288
# 2019-06-14 07:31:40             SCHEDULED    8104              2     418
# 2019-06-14 07:32:25             SCHEDULED    8115              8     287
# 2019-06-14 07:31:50             SCHEDULED    8122             10     415
# 2019-06-14 07:31:06             SCHEDULED    8110              5     417
# 2019-06-14 07:32:33             SCHEDULED    8111              1     286
#
#                       Request Timestamp  Delay   Feed ID
# Arrival Time
# 2019-06-14 07:32:08 2019-06-14 07:31:45      0  13783020
# 2019-06-14 07:31:40 2019-06-14 07:31:45      0  13783085
# 2019-06-14 07:32:25 2019-06-14 07:31:45      0  13783125
# 2019-06-14 07:31:50 2019-06-14 07:31:45      0  13783169
# 2019-06-14 07:31:06 2019-06-14 07:31:45      0  13783175
# 2019-06-14 07:32:33 2019-06-14 07:31:45      0  13783208

# %%
df.reset_index(inplace=True)

# %%
df['Feed ID']=df['Feed ID'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
# Arrival Time             6 non-null datetime64[ns]
# Arrival Delay            6 non-null int64
# Arrival Uncertainty      6 non-null int64
# Departure Delay          6 non-null int64
# Departure Time           6 non-null datetime64[ns]
# Departure Uncertainty    6 non-null int64
# Schedule Relationship    6 non-null object
# Stop ID                  6 non-null object
# Stop Sequence            6 non-null int64
# Trip ID                  6 non-null object
# Request Timestamp        6 non-null datetime64[ns]
# Delay                    6 non-null int64
# Feed ID                  6 non-null int64
# dtypes: datetime64[ns](3), int64(7), object(3)
# memory usage: 704.0+ bytes

# %%
df.head()
# Out:
#          Arrival Time  Arrival Delay  Arrival Uncertainty  Departure Delay  \
# 0 2019-06-14 07:32:08             14                    0               14
# 1 2019-06-14 07:31:40            -24                    0              -24
# 2 2019-06-14 07:32:25            -35                    0              -35
# 3 2019-06-14 07:31:50             33                    0               33
# 4 2019-06-14 07:31:06            -25                    0              -25
#
#        Departure Time  Departure Uncertainty Schedule Relationship Stop ID  \
# 0 2019-06-14 07:32:28                      0             SCHEDULED    8127
# 1 2019-06-14 07:32:00                      0             SCHEDULED    8104
# 2 2019-06-14 07:32:45                      0             SCHEDULED    8115
# 3 2019-06-14 07:32:10                      0             SCHEDULED    8122
# 4 2019-06-14 07:31:26                      0             SCHEDULED    8110
#
#    Stop Sequence Trip ID   Request Timestamp  Delay   Feed ID
# 0              2     288 2019-06-14 07:31:45      0  13783020
# 1              2     418 2019-06-14 07:31:45      0  13783085
# 2              8     287 2019-06-14 07:31:45      0  13783125
# 3             10     415 2019-06-14 07:31:45      0  13783169
# 4              5     417 2019-06-14 07:31:45      0  13783175

# %% [markdown]
# ## Read Postgres and check if these Feed ID exists

# %%
engine = db.create_engine('postgresql://postgres@localhost:5432/noelangelo')
rt_feed = pd.read_sql('SELECT * FROM public.gtfsr_feed LIMIT 10 ', engine)
conn = engine.connect()

# %%
# Create MetaData instance
metadata = MetaData(engine, reflect=True)
# Out:
# /anaconda3/envs/data-science/lib/python3.6/site-packages/ipykernel_launcher.py:2: SADeprecationWarning: The MetaData.reflect flag is deprecated and will be removed in a future release.   Please use the MetaData.reflect() method.

# %%
# Get Table
gtfsr_table = metadata.tables['gtfsr_feed']

# %%
df.head()
# Out:
#          Arrival Time  Arrival Delay  Arrival Uncertainty  Departure Delay  \
# 0 2019-06-06 22:33:07            -17                    0              -17
# 1 2019-06-06 22:33:45            -19                    0              -19
#
#        Departure Time  Departure Uncertainty Schedule Relationship Stop ID  \
# 0 2019-06-06 22:33:27                      0             SCHEDULED    8125
# 1 2019-06-06 22:34:05                      0             SCHEDULED    8106
#
#    Stop Sequence Trip ID   Request Timestamp  Delay  Feed ID
# 0              3     127 2019-06-06 22:33:30      0  5488973
# 1              3     257 2019-06-06 22:33:30      0  5489036

# %%
postgres = pd.read_sql('SELECT * FROM public.gtfsr_feed LIMIT 100', engine)

# %%
postgres
# Out:
#     Arrival Delay        Arrival Time  Arrival Uncertainty  Departure Delay  \
# 0             -24 2019-06-06 22:31:30                    0              -24
# 1             -22 2019-06-06 22:31:42                    0              -22
# 2              23 2019-06-06 22:32:40                    0               23
# 3             -10 2019-06-06 22:31:23                    0              -10
# 4             -24 2019-06-06 22:31:30                    0              -24
# 5             -22 2019-06-06 22:31:42                    0              -22
# 6              23 2019-06-06 22:32:40                    0               23
# 7             -10 2019-06-06 22:31:23                    0              -10
# 8             -24 2019-06-06 22:31:30                    0              -24
# 9             -22 2019-06-06 22:31:42                    0              -22
# 10             23 2019-06-06 22:32:40                    0               23
# 11            -10 2019-06-06 22:31:23                    0              -10
# 12            -24 2019-06-06 22:31:30                    0              -24
# 13            -22 2019-06-06 22:31:42                    0              -22
# 14             23 2019-06-06 22:32:40                    0               23
# 15            -10 2019-06-06 22:31:23                    0              -10
#
#         Departure Time  Departure Uncertainty Schedule Relationship Stop ID  \
# 0  2019-06-06 22:31:50                      0             SCHEDULED    8127
# 1  2019-06-06 22:32:02                      0             SCHEDULED    8104
# 2  2019-06-06 22:33:00                      0             SCHEDULED    8120
# 3  2019-06-06 22:31:43                      0             SCHEDULED    8111
# 4  2019-06-06 22:31:50                      0             SCHEDULED    8127
# 5  2019-06-06 22:32:02                      0             SCHEDULED    8104
# 6  2019-06-06 22:33:00                      0             SCHEDULED    8120
# 7  2019-06-06 22:31:43                      0             SCHEDULED    8111
# 8  2019-06-06 22:31:50                      0             SCHEDULED    8127
# 9  2019-06-06 22:32:02                      0             SCHEDULED    8104
# 10 2019-06-06 22:33:00                      0             SCHEDULED    8120
# 11 2019-06-06 22:31:43                      0             SCHEDULED    8111
# 12 2019-06-06 22:31:50                      0             SCHEDULED    8127
# 13 2019-06-06 22:32:02                      0             SCHEDULED    8104
# 14 2019-06-06 22:33:00                      0             SCHEDULED    8120
# 15 2019-06-06 22:31:43                      0             SCHEDULED    8111
#
#     Stop Sequence Trip ID   Request Timestamp  Delay  Feed ID
# 0               2     127 2019-06-06 22:31:45      0  5487251
# 1               2     257 2019-06-06 22:31:45      0  5487314
# 2               9     256 2019-06-06 22:31:45      0  5487356
# 3               9     126 2019-06-06 22:31:45      0  5487446
# 4               2     127 2019-06-06 22:31:45      0  5487251
# 5               2     257 2019-06-06 22:31:45      0  5487314
# 6               9     256 2019-06-06 22:31:45      0  5487356
# 7               9     126 2019-06-06 22:31:45      0  5487446
# 8               2     127 2019-06-06 22:31:45      0  5487251
# 9               2     257 2019-06-06 22:31:45      0  5487314
# 10              9     256 2019-06-06 22:31:45      0  5487356
# 11              9     126 2019-06-06 22:31:45      0  5487446
# 12              2     127 2019-06-06 22:31:45      0  5487251
# 13              2     257 2019-06-06 22:31:45      0  5487314
# 14              9     256 2019-06-06 22:31:45      0  5487356
# 15              9     126 2019-06-06 22:31:45      0  5487446

# %%
df
# Out:
#          Arrival Time  Arrival Delay  Arrival Uncertainty  Departure Delay  \
# 0 2019-06-06 22:33:07            -17                    0              -17
# 1 2019-06-06 22:33:45            -19                    0              -19
#
#        Departure Time  Departure Uncertainty Schedule Relationship Stop ID  \
# 0 2019-06-06 22:33:27                      0             SCHEDULED    8125
# 1 2019-06-06 22:34:05                      0             SCHEDULED    8106
#
#    Stop Sequence Trip ID   Request Timestamp  Delay  Feed ID
# 0              3     127 2019-06-06 22:33:30      0  5488973
# 1              3     257 2019-06-06 22:33:30      0  5489036

# %%
for feed in list(df['Feed ID']):
    if feed in list(postgres['Feed ID']):
        print('Feed already exists')
    else:
        conn.execute(gtfsr_table.insert(),df.to_dict(orient='records'))

# %%
list(df['Feed ID'])
# Out:
# [5488973, 5489036]

# %%
my_list = []
for idx, val in df.iterrows():
    my_list.append([val['Arrival Time'], val['Stop Sequence'], val['Trip ID']])

# %%
my_list
# Out:
# [[Timestamp('2019-06-06 22:33:07'), 3], [Timestamp('2019-06-06 22:33:45'), 3]]

# %% [markdown]
# ## Elasticsearch

# %%
from elasticsearch import Elasticsearch

# %%
es=Elasticsearch([{'host':'localhost','port':9200, 'http_auth':('elastic', 'changeme')}])

# %%
for idx, record in enumerate(df.to_dict(orient='records'), 1):
    es.index(index='transportcanberra',doc_type='lightrail',body=record, id=record['Feed ID'])
    print(record['Feed ID'])
# Out:
# 13783020
# 13783085
# 13783125
# 13783169
# 13783175
# 13783208

# %%
res = es.get(index='transportcanberra',doc_type='lightrail',id=13783020)

# %%
pd.DataFrame.from_dict(res)
# Out:
#                                   _index      _type       _id  _version  \
# Arrival Delay          transportcanberra  lightrail  13783020         4
# Arrival Time           transportcanberra  lightrail  13783020         4
# Arrival Uncertainty    transportcanberra  lightrail  13783020         4
# Delay                  transportcanberra  lightrail  13783020         4
# Departure Delay        transportcanberra  lightrail  13783020         4
# Departure Time         transportcanberra  lightrail  13783020         4
# Departure Uncertainty  transportcanberra  lightrail  13783020         4
# Feed ID                transportcanberra  lightrail  13783020         4
# Request Timestamp      transportcanberra  lightrail  13783020         4
# Schedule Relationship  transportcanberra  lightrail  13783020         4
# Stop ID                transportcanberra  lightrail  13783020         4
# Stop Sequence          transportcanberra  lightrail  13783020         4
# Trip ID                transportcanberra  lightrail  13783020         4
#
#                        _seq_no  _primary_term  found              _source
# Arrival Delay               18              1   True                   14
# Arrival Time                18              1   True  2019-06-14T07:32:08
# Arrival Uncertainty         18              1   True                    0
# Delay                       18              1   True                    0
# Departure Delay             18              1   True                   14
# Departure Time              18              1   True  2019-06-14T07:32:28
# Departure Uncertainty       18              1   True                    0
# Feed ID                     18              1   True             13783020
# Request Timestamp           18              1   True  2019-06-14T07:31:45
# Schedule Relationship       18              1   True            SCHEDULED
# Stop ID                     18              1   True                 8127
# Stop Sequence               18              1   True                    2
# Trip ID                     18              1   True                  288

# %%
doc = {
        'size' : 10000,
        'query': {
            'match_all' : {}
       }
   }
res = es.search(index='transportcanberra', body=doc, scroll='1m')

# %%
pd.DataFrame.from_dict(res['hits']['hits'])
# Out:
#         _id             _index  _score  \
# 0  13783020  transportcanberra     1.0
# 1  13783085  transportcanberra     1.0
# 2  13783125  transportcanberra     1.0
# 3  13783169  transportcanberra     1.0
# 4  13783175  transportcanberra     1.0
# 5  13783208  transportcanberra     1.0
#
#                                              _source      _type
# 0  {'Arrival Time': '2019-06-14T07:32:08', 'Arriv...  lightrail
# 1  {'Arrival Time': '2019-06-14T07:31:40', 'Arriv...  lightrail
# 2  {'Arrival Time': '2019-06-14T07:32:25', 'Arriv...  lightrail
# 3  {'Arrival Time': '2019-06-14T07:31:50', 'Arriv...  lightrail
# 4  {'Arrival Time': '2019-06-14T07:31:06', 'Arriv...  lightrail
# 5  {'Arrival Time': '2019-06-14T07:32:33', 'Arriv...  lightrail
