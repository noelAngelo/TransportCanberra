# %%
import requests
import json
import pandas

# %%
json_normalize(json.loads(requests.get('https://www.data.act.gov.au/resource/r9a8-xw6s.json').content))
# Out:
#     arrival_delay             arrival_time arrivaluncertainty depature_delay  \
# 0             179  2019-06-16T08:26:59.000                  0            179
# 1              26  2019-06-16T08:54:26.000                  0             26
# 2              49  2019-06-16T09:24:49.000                  0             49
# 3              22  2019-06-16T09:54:22.000                  0             22
# 4              23  2019-06-16T10:24:23.000                  0             23
# 5              59  2019-06-16T10:54:59.000                  0             59
# 6             116  2019-06-16T11:25:56.000                  0            116
# 7              96  2019-06-16T11:55:36.000                  0             96
# 8              94  2019-06-16T12:25:34.000                  0             94
# 9               0  2019-06-16T12:30:00.000                  1              0
# 10              0  2019-06-16T12:31:54.000                  1              0
# ...
